# %% [markdown]
# # E.D.A on VISA Dataset

# %% [markdown]
# ## Importing all necessary tools for EDA

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Dataset Description
# ### This is Google Play Store Apps Data, the  dataset Sourse -- (Kaggle)
# ### This dataset have an all details about apps like name, ratings, total_install etc.

# %% [markdown]
# ## Columns of the dataset are as follows:
#
# 1) App (Name)
#
# 2) Category (App)
#
# 3) Rating (App)
#
# 4) Reviews (User)
#
# 5) Size (App)
#
# 6) Installs (App)
#
# 7) Type (Free/Paid)
#
# 8) Price (App)
#
# 9) Content Rating (Everyone/Teenager/Adult)
#
# 10) Genres (Detailed Category)
#
# 11) Last Updated (App)
#
# 12) Current Version (App)
#
# 13) Android Version (Support)

# %% [markdown]
# ## Loading Google Play Store Dataset

# %%
df_google = pd.read_csv('googleplaystore.csv')

# %% [markdown]
# # 1: Manking an Profile of the Dataset

# %%
df_google
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## colclusion:-- We have Table of (10841 X 13), where we have 13 columns/Attributes and 10841 rows/records

# %%
# Finding a types of Attributes we have
df_google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Colclusions:--
#
# ### (i) We have total 13 columns where all are Categorical except 1 column, which is Ratings this is a Continuous Numerical.
# ### (ii) Memory Size of the file is 1.1 MB
# ### (iii) We also have a null values in Some Columns.
# ### (iii) Note-- Here Price Column is Categorical.

# %%
# Finding an Number of Unique Values of each Column
all_columns = df_google.columns
all_columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_google.nunique()
# Out:
# App               9660
# Category            34
# Rating              40
# Reviews           6002
# Size               462
# Installs            22
# Type                 3
# Price               93
# Content Rating       6
# Genres             120
# Last Updated      1378
# Current Ver       2832
# Android Ver         33
# dtype: int64

# %%
#Now, let's inspect the first 5 distinct values of all variables:
for i in all_columns:
    print(i+'   ----  ',df_google[i].unique()[:5],'\n')
# Out:
# App   ----   ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps'
#  'Sketch - Draw & Paint' 'Pixel Draw - Number Art Coloring Book']
#
# Category   ----   ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS']
#
# Rating   ----   [4.1 3.9 4.7 4.5 4.3]
#
# Reviews   ----   ['159' '967' '87510' '215644' '167']
#
# Size   ----   ['19M' '14M' '8.7M' '25M' '2.8M']
#
# Installs   ----   ['10,000+' '500,000+' '5,000,000+' '50,000,000+' '100,000+']
#
# Type   ----   ['Free' 'Paid' nan '0']
#
# Price   ----   ['0' '$4.99' '$3.99' '$6.99' '$1.49']
#
# Content Rating   ----   ['Everyone' 'Teen' 'Everyone 10+' 'Mature 17+' 'Adults only 18+']
#
# Genres   ----   ['Art & Design' 'Art & Design;Pretend Play' 'Art & Design;Creativity'
#  'Art & Design;Action & Adventure' 'Auto & Vehicles']
#
# Last Updated   ----   ['January 7, 2018' 'January 15, 2018' 'August 1, 2018' 'June 8, 2018'
# ...

# %% [markdown]
# ## Colclusions:--
# ### (i) In 10481 Apps we have 9660 Apps are uniques which is good.
# ### (ii) As we see we have 9660 unique apps but in respect to these uniqe apps we have only 22 unique values of Installs columns (This Column Shows the Total Number of Downloads of the particular App).
# ### (iii) We have only 120 different types of Apps genres in our Dataset.
# ### (iv) In ratings we have 40 differeent-different Values which is good.
# ### (v) In This Dataset apps are divided in 34 different Category's.

# %%
# Looking up Duplicate records
df_google.duplicated().sum()
# Out:
# 483

# %% [markdown]
# ## Conclusions:-- In this Dataset we have a 483 duplicate records.

# %%
# Looking up the Null Values
df_google.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
total = sum([df_google[i].isnull().sum() for i in all_columns])
total
# Out:
# 1487

# %%
null_value_columns = [i for i in all_columns if df_google[i].isnull().sum()>0]
null_value_columns
# Out:
# ['Rating', 'Type', 'Content Rating', 'Current Ver', 'Android Ver']

# %% [markdown]
# ## Conclusions:--
#
# ### (i) Total Number of Null Values in this dataset is -- 1487
# ### (ii) In our Dataset Five Columns ('Rating', 'Type', 'Content Rating', 'Current Ver', 'Android Ver') have a Some Null Values.
# ### (iii) In all Null Values approx 99% null Values are only in the (Rating) Column.

# %% [markdown]
# # 2: Stats based Analysis

# %%
# This function is only works with numerical columns
df_google.describe().T
# Out:
#          count      mean       std  min  25%  50%  75%   max
# Rating  9367.0  4.193338  0.537431  1.0  4.0  4.3  4.5  19.0

# %%
df_google['Rating'].median()
# Out:
# 4.3

# %% [markdown]
# ## Colclusions:--
#
# ### (i) Max rating in Ratings Columns is 19.0 which cann't be possible because in google play store ratings range is 1-5 so this will we an value error we have to handle this in feauture engineering process.
# ### (ii) Minimum rating is 1 provide by the users to the apps in google play store.
# ### (iii) We have an outliers in the ratings columns which affect the mean so we consider median for finding an central value which is 4.3 that means most of the user are satisfied with the overall performance of google play store apps.

# %%
# We can also do some stats analysis on the categorical columns with the help of describes functions.
df_google.describe(include='object').T
# Out:
#                 count unique                 top   freq
# App             10841   9660              ROBLOX      9
# Category        10841     34              FAMILY   1972
# Reviews         10841   6002                   0    596
# Size            10841    462  Varies with device   1695
# Installs        10841     22          1,000,000+   1579
# Type            10840      3                Free  10039
# Price           10841     93                   0  10040
# Content Rating  10840      6            Everyone   8714
# Genres          10841    120               Tools    842
# Last Updated    10841   1378      August 3, 2018    326
# Current Ver     10833   2832  Varies with device   1459
# Android Ver     10838     33          4.1 and up   2451

# %% [markdown]
# ## Conclusions:--
#
# ### (i) We can see that the most apps are from the Family category.
# ### (ii)  Most apps already have an more that 1 Million Installation.
# ### (iii) From all the apps approx 99% apps are free means they have price 0.
# ### (iv) Dataset have a Mostly apps are from Tools Genres.

# %% [markdown]
# # 3: Graph Based Analysis

# %% [markdown]
# ### univariate Analysis

# %%
# ratings
sns.distplot(df_google['Rating'])
# Out:
# /home/aryan/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %% [markdown]
# ## Conclusions: --
# ### We see that ratings is a Right log normal distribution so we have a some outliers in our Ratings Columns

# %%
# Determining a frequency of all unique vales of Category Attribute
sns.catplot(data=df_google, y="Category", kind="count",palette="pastel", edgecolor=".6",height=10, aspect=1)

# %% [markdown]
# ## Conclusions:--
# ### We see that Our Top three Categorys are -- (Family, Game and Tools) Which covers the approx 35% of data of total distribution of category Column.

# %%
# Geting insights from Installs Column
sns.catplot(data=df_google, y="Installs", kind="count",palette="pastel", edgecolor=".6",height=10, aspect=1)

# %% [markdown]
# ## Colclusions:--
#
# ### (1) Most apps have alrady have an 1Million+ downloads.
# ### (2) In the dataset we have some apps who installs more than 1Billion times.
# ### (3) Approximately 11-12% apps are installed more than 10Million times.
# ### (4) In the whole dataset approxly 15% apps are only installed between 0 to 1000.

# %%
# Determining a Size variable
df_google.groupby('Size')['Size'].count()
# Out:
# Size
# 1,000+                   1
# 1.0M                     7
# 1.1M                    32
# 1.2M                    41
# 1.3M                    35
#                       ...
# 98M                     16
# 992k                     1
# 994k                     1
# 99M                     39
# Varies with device    1695
# Name: Size, Length: 462, dtype: int64

# %%
df_google['Size'].mode()
# Out:
# 0    Varies with device
# dtype: object

# %%
# Determining or inpect a Size Variable which hplds a size of the app
sns.catplot(data=df_google, y="Size", kind="count",palette="pastel", edgecolor=".6",height=100, aspect=0.1)

# %%
sns.boxplot(data=df_google, x='Rating')
# Out:
# <AxesSubplot:xlabel='Rating'>

# %%
sns.violinplot(data=df_google, x='Rating')
# Out:
# <AxesSubplot:xlabel='Rating'>

# %%
sns.distplot(df_google['Rating'])
# Out:
# /home/aryan/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %% [markdown]
# ## Conclusion:--
#
# ### As we see with the help of distribution and box plot there are many outliers from left side of the distribution and very few from right hand side.

# %% [markdown]
# # Highlieghts Points of this Analysis
#
# ## In 5 Columns ('Rating', 'Type', 'Content Rating', 'Current Ver', 'Android Ver') have a missing Values Specially the ratings Column becausr in total null values 99% are in the Ratings Column so we need to Handle them.
#
# ## We have an Outliers in the Ratings Column
#
# ## There are some Categorial Features which we have to encode them modeling like Prices, Size etc .
#
# ## There is one Categorical Column Datatime which we need to convert it into a datetime format/type

# %% [markdown]
# # Final Conclusion :-- This dataset need an Feature_Engineering and Preprocessing like encoding, transformation, Scaling to make it usefull for model creation.
